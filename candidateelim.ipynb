# %%
import numpy as np
import pandas as pd

data = pd.read_csv("abc.csv")
concepts = np.array(data.iloc[:, 0:-1])
print("\nInstances are:\n", concepts)
target = np.array(data.iloc[:, -1])
print("\nTarget Values are: ", target)

def learn(concepts, target):
    positive_instances = [concepts[i] for i in range(len(concepts)) if target[i] == 'yes']
    specific_h = positive_instances[0].copy()
    print("\nInitialization of specific_h and generic_h")
    print("\nSpecific Boundary: ", specific_h)
    general_h = [['?' for _ in range(len(specific_h))] for _ in range(len(specific_h))]
    print("\nGeneric Boundary: ", general_h)

    for i, h in enumerate(concepts):
        print("\nInstance", i + 1, "is ", h)
        if target[i] == "yes":
            print("Instance is Positive ")
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    specific_h[x] = '?'
                    general_h[x][x] = '?'

        if target[i] == "no":
            print("Instance is Negative ")
            for x in range(len(specific_h)):
                if h[x] != specific_h[x]:
                    general_h[x][x] = specific_h[x]
                else:
                    general_h[x][x] = '?'

        print("Specific Boundary after ", i + 1, "Instance is ", specific_h)
        print("Generic Boundary after ", i + 1, "Instance is ", general_h)
        print("\n")

    # Clean up the redundant hypotheses in the generic boundary
    indices = [i for i, val in enumerate(general_h) if val == ['?' for _ in range(len(specific_h))]]
    for i in indices:
        general_h.remove(['?' for _ in range(len(specific_h))])
    return specific_h, general_h

s_final, g_final = learn(concepts, target)

print("Final Specific_h: ", s_final, sep="\n")
print("Final General_h: ", g_final, sep="\n")
# Out:
# Instances are:
#  [['big' 'red' 'circle']
#  ['small' 'red' 'triangle']
#  ['small' 'red' 'circle']
#  ['big' 'blue' 'circle']
#  ['small' 'blue' 'circle']]
#
# Target Values are:  ['no' 'no' 'yes' 'no' 'yes']
#
# Initialization of specific_h and generic_h
#
# Specific Boundary:  ['small' 'red' 'circle']
#
# Generic Boundary:  [['?', '?', '?'], ['?', '?', '?'], ['?', '?', '?']]
#
# Instance 1 is  ['big' 'red' 'circle']
# Instance is Negative
# Specific Boundary after  1 Instance is  ['small' 'red' 'circle']
# Generic Boundary after  1 Instance is  [['small', '?', '?'], ['?', '?', '?'], ['?', '?', '?']]
#
#
#
# Instance 2 is  ['small' 'red' 'triangle']
# Instance is Negative
# Specific Boundary after  2 Instance is  ['small' 'red' 'circle']
# Generic Boundary after  2 Instance is  [['?', '?', '?'], ['?', '?', '?'], ['?', '?', 'circle']]
#
#
#
# Instance 3 is  ['small' 'red' 'circle']
# Instance is Positive
# Specific Boundary after  3 Instance is  ['small' 'red' 'circle']
# Generic Boundary after  3 Instance is  [['?', '?', '?'], ['?', '?', '?'], ['?', '?', 'circle']]
#
#
#
# Instance 4 is  ['big' 'blue' 'circle']
# Instance is Negative
# Specific Boundary after  4 Instance is  ['small' 'red' 'circle']
# Generic Boundary after  4 Instance is  [['small', '?', '?'], ['?', 'red', '?'], ['?', '?', '?']]
#
#
#
# Instance 5 is  ['small' 'blue' 'circle']
# Instance is Positive
# Specific Boundary after  5 Instance is  ['small' '?' 'circle']
# Generic Boundary after  5 Instance is  [['small', '?', '?'], ['?', '?', '?'], ['?', '?', '?']]
#
#
# Final Specific_h:
# ['small' '?' 'circle']
# Final General_h:
# [['small', '?', '?']]
